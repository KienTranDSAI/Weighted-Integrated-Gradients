# %%
import os
dataset_dir = "./data"
images_raw_names = [i for i in os.listdir(dataset_dir + "/Image")]
images_path = [dataset_dir + f"/Image/{name}" for name in images_raw_names]
masks_path = [dataset_dir + f"/Mask/{name}" for name in images_raw_names]

# %%
images_path
# Out:
# ['./data/Image/000000008471.png',
#  './data/Image/000000012959.png',
#  './data/Image/000000014049.png',
#  './data/Image/000000035927.png',
#  './data/Image/000000038290.png',
#  './data/Image/000000040593.png',
#  './data/Image/000000049643.png',
#  './data/Image/000000050242.png',
#  './data/Image/000000058089.png',
#  './data/Image/000000059012.png',
#  './data/Image/000000067814.png',
#  './data/Image/000000074798.png',
#  './data/Image/000000082405.png',
#  './data/Image/000000105058.png',
#  './data/Image/000000109177.png',
#  './data/Image/000000110593.png',
#  './data/Image/000000116603.png',
#  './data/Image/000000128431.png',
#  './data/Image/000000129553.png',
#  './data/Image/000000149388.png',
#  './data/Image/000000149555.png',
#  './data/Image/000000151200.png',
#  './data/Image/000000152108.png',
#  './data/Image/000000159640.png',
#  './data/Image/000000162055.png',
#  './data/Image/000000162584.png',
#  './data/Image/000000162650.png',
# ...
